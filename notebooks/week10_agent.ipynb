# %% [markdown]
# # Week 10: Agent (Optional)
#
# SiteLens AI — Optional thin agent layer (bbox in → report out).
#
# **Topic:** Agentic AI, MCP
# **Dates:** May 24–28 2026
# **Deliverable:** Optional. Consolidation/recovery time if Weeks 8–9 ran hot.
#
# **Status:** Placeholder. Held loosely — implement only if Weeks 8–9 are complete.

# %%
# Week 10 implementation (optional)
