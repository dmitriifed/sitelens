# %% [markdown]
# # Week 11: CNN Classifier
#
# SiteLens AI — CV classifier on Noto crops + scene-level pipeline + per-class F1 evaluation.
#
# **Topic:** Capstone build (scope due Mon Jun 1)
# **Dates:** May 31–Jun 4 2026
# **Deliverable:** CNN damage classifier, evaluation against held-out Vescovo et al. test split.
#
# **Status:** Placeholder. To be implemented Week 11.

# %%
# Week 11 implementation
